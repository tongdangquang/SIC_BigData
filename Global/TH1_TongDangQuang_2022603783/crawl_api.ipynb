# %%
import requests
import json

def get_home_collections(latitude, longitude):
    url = "https://gw.be.com.vn/api/v1/be-merchant-gateway/web/customer/get_home_collections"

    payload = json.dumps({
    "locale": "vi",
    "client_info": {
        "locale": "vi",
        "device_type": 3
    },
    "latitude": latitude,
    "longitude": longitude
    })
    headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0NTgwNTMwMSwiaWF0IjoxNzQ1NzE4OTAxLCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.RzvaYPRmdMBlrkxWf7wntp4e6t-Lea-trm7qu5D6m9Y',
    'content-type': 'application/json'
    }
    response = requests.request("POST", url, headers=headers, data=payload)
    return json.loads(response.text)

# %%
def get_restaurants(collection_id, page, limit, latitude, longitude):
    url = "https://gw.be.com.vn/api/v1/be-marketplace/web/collection/items/restaurants"

    payload = json.dumps({
    "collection_id": f"{collection_id}",
    "page": page,
    "limit": limit,
    "latitude": latitude,
    "longitude": longitude
    })
    headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0NTgwNjE3NiwiaWF0IjoxNzQ1NzE5Nzc2LCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.5npsvO0KQtBqIgSbjE-JM9TFzR_yyqwJaIwQLLquaLY',
    'content-type': 'application/json'
    }
    response = requests.request("POST", url, headers=headers, data=payload)
    return (json.loads(response.text))

# %%
def get_detail(restaurant_id, latitude, longitude):
    url = "https://gw.be.com.vn/api/v1/be-marketplace/web/restaurant/detail"

    payload = json.dumps({
    "restaurant_id": restaurant_id,
    "latitude": latitude,
    "longitude": longitude
    })
    headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0NTgxMDAxOSwiaWF0IjoxNzQ1NzIzNjE5LCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.gLV20YpJNDYsYJxaKf3Tgi7O28qn4Uszi2REfW8ppyo',
    'content-type': 'application/json'
    }
    response = requests.request("POST", url, headers=headers, data=payload)
    return json.loads(response.text)

# %%
latitude = 10.77253621500006
longitude = 106.69798153800008

collection_ids = get_home_collections(latitude, longitude)
for data_ids in collection_ids['collections']:
    print(f"START CRAWLER ID: {data_ids['id']} - CATEGORY: {data_ids['name']}")
    for page_id in range(1, 2):
        restaurants_data = get_restaurants(data_ids["id"], page_id, 1, latitude, longitude)
        
        for restaurant in restaurants_data["data"]:
            print("\tName:", restaurant['name'])
            print("\tAddress:", restaurant['address'])
            print("\tRestaurant_id:", restaurant['restaurant_id'])

            detail_restaurant = get_detail(restaurant['restaurant_id'], latitude, longitude)
            for i, detail in enumerate(detail_restaurant['data']['categories']):
                print("\t\tDish position:", i + 1)
                print("\t\tDish name:", detail['category_name'])
                for item in detail['items']:
                    print("\t\t\tItem Name:", item['item_name'], ", item price: ", item['display_price'])
                break
            break
        break
    print(f"END CRAWLER ID: {data_ids['id']} - CATEGORY: {data_ids['name']}")
    print()
# Out:
# START CRAWLER ID: 228 - CATEGORY: Đồ uống
# 	Name: Cafe Tonkin Cottage - Lý Tự Trọng
# 	Address: 91 Lý Tự Trọng, Bến Thành, Quận 1, Hồ Chí Minh, Việt Nam
# 	Restaurant_id: 29034
# 		Dish position: 1
# 		Dish name: TONKIN SIGNATURE: CAFE ĐỈNH
# 			Item Name: CAFE KEM TRỨNG - Egg cream coffee , item price:  59.000
# 			Item Name: NÂU TONKIN - Một trong những ly cafe sữa đá ngon nhất Sài Gòn , item price:  49.000
# 			Item Name: TONKIN COLD BREW - Cafe Cold Brew Tonkin , item price:  59.000
# 			Item Name: HANOI COLD BREW - Cafe Cold Brew Hà Nội , item price:  59.000
# END CRAWLER ID: 228 - CATEGORY: Đồ uống
#
# START CRAWLER ID: 230 - CATEGORY: Thức Ăn Nhanh
# 	Name: Burger - Kebab - Taco - Falafel - Hotdog - Smoothies - Milktea Gotcha
# 	Address: 267 Đề Thám, Phạm Ngũ Lão, Quận 1, Hồ Chí Minh, Việt Nam
# 	Restaurant_id: 8567
# 		Dish position: 1
# 		Dish name: Happy Breakfast
# 			Item Name: Banh mi+ Coffee , item price:  59.000
# ...
